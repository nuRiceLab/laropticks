# %%
import matplotlib.pyplot as plt

import numpy as np
import uproot as up

# %%
f1=up.open("/home/rice/Projects/DUNE_Opticks/aaron_test/aaron_paper/work/new_Rice/PDFast_detsim_Reco_hist.root")
f2=up.open("/home/rice/Projects/DUNE_Opticks/aaron_test/aaron_paper/work/new_Rice/Opticks_detsim_Reco_hist.root")

# %%
f1["opflashana/PerOpHitTree"].keys()
# Out:
# ['EventID',
#  'HitID',
#  'OpChannel',
#  'PeakTimeAbs',
#  'PeakTime',
#  'Frame',
#  'Width',
#  'Area',
#  'Amplitude',
#  'PE',
#  'FastToTotal']

# %%
_=plt.hist(f1["opflashana/PerOpHitTree/OpChannel"].array().to_numpy(),bins=100,density=True,alpha=0.6)
_=plt.hist(f2["opflashana/PerOpHitTree/OpChannel"].array().to_numpy(),bins=100,density=True,alpha=0.5)
