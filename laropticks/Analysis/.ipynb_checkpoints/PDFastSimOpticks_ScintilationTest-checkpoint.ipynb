# %%
import uproot as up
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
f=up.open("/home/rice/Projects/DUNE_Opticks/Build_Test/work/test.root")
#f=up.open("/home/rice/Projects/DUNE_Opticks/OlderG4OpticksGDML/dune10kt_v5_refactored_1x2x6_e_3GeV.root")
f["OpticksHits"].keys()
# Out:
# ['evtID',
#  'parent_Id',
#  'hit_Id',
#  'SensorID',
#  'x',
#  'y',
#  'z',
#  't',
#  'wavelength',
#  'boundary']

# %%
evtID=f["OpticksHits/evtID"].array().to_numpy()
print(evtID)
len(np.unique(evtID, return_inverse=False))
# Out:
# [   1    1    1 ... 3375 3375 3375]
# 3366

# %%
event=0
IDMask=evtID>event
print(evtID[IDMask])
# Out:
# [   1    1    1 ... 3375 3375 3375]

# %%
#parentID=f["OpticksHits/parent_Id"].array().to_numpy()[IDMask]
x=f["OpticksHits/x"].array().to_numpy()[IDMask]
y=f["OpticksHits/y"].array().to_numpy()[IDMask]
z=f["OpticksHits/z"].array().to_numpy()[IDMask]
t=f["OpticksHits/t"].array().to_numpy()[IDMask]
boundary=f["OpticksHits/boundary"].array().to_numpy()[IDMask]
wave=f["OpticksHits/wavelength"].array().to_numpy()[IDMask]
SId=f["OpticksHits/SensorID"].array().to_numpy()[IDMask]

# %% [markdown]
# x=f["OpticksHits/x"].array().to_numpy()[IDMask]
# y=f["OpticksHits/y"].array().to_numpy()[IDMask]
# z=f["OpticksHits/z"].array().to_numpy()[IDMask]
# t=f["OpticksHits/t"].array().to_numpy()[IDMask]
# wave=f["OpticksHits/wavelength"].array().to_numpy()[IDMask]
# SId=f["OpticksHits/SensorID"].array().to_numpy()[IDMask]

# %%
_=plt.hist2d(z,y,bins=300, cmin=0,cmax=2)
plt.colorbar()
plt.xlabel("z (mm)")
plt.ylabel("y (mm)")
#plt.ylim(-800,800)
#plt.xlim(120,1300)
# Out:
# Text(0, 0.5, 'y (mm)')

# %%
unique_ids, inv = np.unique(SId, return_inverse=True)
print(unique_ids)
print(inv)
# Out:
# [ 64  82  84  86  88  98 103 108 115 118 119 121 124 126 127 128 129 132
#  135 136 137 138 139 141 142 143 144 145 146 147 148 149 151 152 153 154
#  155 156 157 158 159 160 161 162 163 164 165 166 167 168 169 171 172 173
#  174 175 176 177 178 179 181 182 183 184 185 186 187 188 189 191 192 193
#  194 195 196 197 198 199 200 201 202 203 204 205 206 207 208 209 210 211
#  212 213 214 215 216 217 218 219 221 222 223 224 225 226 227 228 229 230
#  231 232 233 234 235 236 237 238 239 263 277 283 297 302 305 310 314 320
#  323 326 330 331 333 336 340 341 344 345 348 350 352 353 360 361 362 363
#  365 366 367 370 371 372 373 374 376 379 380 381 382 383 384 385 386 387
#  388 390 391 392 393 394 395 396 397 398 400 401 402 403 404 405 406 407
#  408 409 410 411 412 413 414 415 416 417 418 419 420 421 422 423 424 425
#  426 427 428 429 430 431 432 433 434 435 436 437 438 439 440 441 442 443
#  444 445 446 447 448 449 450 451 452 453 454 455 456 457 458 459 460 461
#  462 463 464 465 466 467 468 470 471 472 473 474 475 476 477 478 479]
# [241 233 232 ... 106  96 106]

# %%
_=plt.hist(SId,bins=100,histtype="step")
plt.xlabel("Sensor IDs")
plt.semilogy()
# Out:
# []

# %%
_=plt.hist(wave,bins=300,histtype="step")
plt.xlabel("Wavelength")
#plt.semilogy()
# Out:
# Text(0.5, 0, 'Wavelength')

# %%
_=plt.hist(t,bins=300,histtype="step")
plt.xlabel("time")
plt.semilogy()
# Out:
# []
